# %%
#https://stackabuse.com/linked-lists-in-detail-with-python-examples-single-linked-lists/
#creating class 
class Node:
    def __init__(self,data):
        self.data = data
        self.link = None
#creating head node which points to NULL 
class Linkedlist:
    def __init__(self):
        self.head = None
    def insert_begin(self,data):
        new = Node(data)
        new.link = self.head
        self.head = new
    def insert_end(self,data):
        new = Node(data)
        if self.head is None:
            self.head = new
           # return
        temp = self.head
        while temp.link is not None:
            temp = temp.link
        temp.link = new
    #traverse
    def traverse(self):
        if self.head is None:
            print("No element in the list")
            return 
        else:
            temp = self.head
            while temp is not None:
                print(temp.data,end = ' ')
                temp = temp.link
    def countele(self):
        temp = self.head
        count = 0
        while temp is not None:
            count = count + 1
            temp = temp.link
        return count
obj = Linkedlist()

obj.insert_begin(10)
obj.insert_begin(20)
obj.insert_begin(30)
obj.insert_begin(40)
obj.insert_end(50)
obj.traverse()
obj.countele()
# Out:
# 40 30 20 10 50
# 5

# %%
#https://stackabuse.com/linked-lists-in-detail-with-python-examples-single-linked-lists/
#creating class 
class Node:
    def __init__(self,data):
        self.data = data
        self.link = None
#creating head node which points to NULL 
class Linkedlist:
    def __init__(self):
        self.head = None
    def insert(self,data):
        new = Node(data)
        if self.head is None:
            self.head = new
        
    def insert_begin(self,data):
        new = Node(data)
        new.link = self.head
        self.head = new
    def insert_end(self,data):
        new = Node(data)
        if self.head is None:
            self.head = new
        else:
            temp = self.head
            while temp.link is not None:
                temp = temp.link
            temp.link = new
    #traverse
    def traverse(self):
        if self.head is None:
            print("No element in the list")
        else:
            temp = self.head
            while temp is not None:
                print(temp.data,end = ' ')
                temp = temp.link
    def countele(self):
        temp = self.head
        count = 0
        while temp is not None:
            count = count + 1
            temp = temp.link
        print("ELements in the list : {0}".format(count))
        #return count
    def search(self,x):
        if self.head is None:
            print("No elements to search")
        else:
            temp = self.head
            while temp is not None:
                if temp.data == x:
                    print("{0} is found".format(x))
                    return
                temp = temp.link
            print("{0} is not found".format(x))
            
obj = Linkedlist()
obj.insert_begin(10)
obj.insert_begin(20)
obj.insert_begin(30)
obj.insert_begin(40)
obj.insert_end(50)
obj.insert_end(33)
obj.insert_end(44)
obj.countele()   
obj.traverse()
x=int(input("\nENter element to search:"))
obj.search(x)
# Out:
# ELements in the list : 7
# 40 30 20 10 50 33 44
# ENter element to search:33
# 33 is found

# %%
#https://stackabuse.com/linked-lists-in-detail-with-python-examples-single-linked-lists/
#creating class 
class Node:
    def __init__(self,data):
        self.data = data
        self.link = None
#creating head node which points to NULL 
class Linkedlist:
    def __init__(self):
        self.head = None
    def insert(self,data):
        new = Node(data)
        if self.head is None:
            self.head = new
        
    def insert_begin(self,data):
        new = Node(data)
        new.link = self.head
        self.head = new
    def insert_end(self,data):
        new = Node(data)
        if self.head is None:
            self.head = new
        else:
            temp = self.head
            while temp.link is not None:
                temp = temp.link
            temp.link = new
    def traverse(self):
        if self.head is None:
            print("No element in the list")
        else:
            temp = self.head
            while temp is not None:
                print(temp.data)
                temp = temp.link
    def find_mid(self):
        temp = self.head
        count = 0
        while temp is not None:
            count = count + 1
            temp = temp.link
        mid = int(count/2)
        print("Mid:",mid)
        temp = self.head
        count = 0
        while temp is not None:
            count = count + 1
            if count == mid:
                print("Middle element is : {0}".format(temp.data))
                return
            temp = temp.link
    def countele(self):
        temp = self.head
        count = 0
        while temp is not None:
            count = count + 1
            temp = temp.link
        print("ELements in the list : {0}".format(count))
        #return count
    def search(self):
        x=int(input("\nENter element to search:"))
        if self.head is None:
            print("No elements to search")
        else:
            temp = self.head
            while temp is not None:
                if temp.data == x:
                    print("{0} is found".format(x))
                    return
                temp = temp.link
            print("{0} is not found".format(x))
            
obj = Linkedlist()
obj.insert_begin(10)
obj.insert_begin(20)
obj.insert_begin(30)
obj.insert_begin(40)
obj.insert_end(50)
obj.insert_end(33)
obj.insert_end(44)
obj.countele()   
obj.traverse()
#obj.search()
obj.find_mid()
# Out:
# ELements in the list : 7
# 40
# 30
# 20
# 10
# 50
# 33
# 44
# Mid: 3
# Count: 1
# Count: 2
# Count: 3
# Middle element is : 20

# %%
#https://stackabuse.com/linked-lists-in-detail-with-python-examples-single-linked-lists/
#creating class 
class Node:
    def __init__(self,data):
        self.data = data
        self.link = None
#creating head node which points to NULL 
class Linkedlist:
    def __init__(self):
        self.head = None
    def insert(self,data):
        new = Node(data)
        if self.head is None:
            self.head = new
        
    def insert_begin(self,data):
        new = Node(data)
        new.link = self.head
        self.head = new
    def insert_end(self,data):
        new = Node(data)
        if self.head is None:
            self.head = new
        else:
            temp = self.head
            while temp.link is not None:
                temp = temp.link
            temp.link = new
    def traverse(self):
        if self.head is None:
            print("No element in the list")
        else:
            temp = self.head
            while temp is not None:
                print(temp.data)
                temp = temp.link
    def find_mid(self):
        slow = self.head
        fast = fast.head
        count = 0
        while fast and fast.link:
            count = count + 1 
            slow = slow.link
            fast = fast.link.link
        print("Middle elemet is at {0} poistion:".format(count))
        print("Middle elemet is {0} :".format(slow.data))
    def countele(self):
        temp = self.head
        count = 0
        while temp is not None:
            count = count + 1
            temp = temp.link
        print("ELements in the list : {0}".format(count))
        #return count
    def search(self):
        x=int(input("\nENter element to search:"))
        if self.head is None:
            print("No elements to search")
        else:
            temp = self.head
            while temp is not None:
                if temp.data == x:
                    print("{0} is found".format(x))
                    return
                temp = temp.link
            print("{0} is not found".format(x))
            
obj = Linkedlist()
obj.insert_begin(10)
obj.insert_begin(20)
obj.insert_begin(30)
obj.insert_begin(40)
obj.insert_end(50)
obj.insert_end(33)
obj.insert_end(44)
obj.countele()   
obj.traverse()
#obj.search()
obj.find_mid()
# Out:
# ELements in the list : 7
# 40
# 30
# 20
# 10
# 50
# 33
# 44
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-3-6db1a512885f> in <module>
#      77 obj.traverse()
#      78 #obj.search()
# ---> 79 obj.find_mid()
#
# <ipython-input-3-6db1a512885f> in find_mid(self)
#      37     def find_mid(self):
#      38         slow = self.head
# ---> 39         fast = fast.head
#      40         count = 0
#      41         while fast and fast.link:
#
# UnboundLocalError: local variable 'fast' referenced before assignment

# %%
#https://stackabuse.com/linked-lists-in-detail-with-python-examples-single-linked-lists/
#creating class 
class Node:
    def __init__(self,data):
        self.data = data
        self.link = None
#creating head node which points to NULL 
class Linkedlist:
    def __init__(self):
        self.head = None
    def insert(self,data):
        new = Node(data)
        if self.head is None:
            self.head = new
        
    def insert_begin(self,data):
        new = Node(data)
        new.link = self.head
        self.head = new
    def insert_end(self,data):
        new = Node(data)
        if self.head is None:
            self.head = new
        else:
            temp = self.head
            while temp.link is not None:
                temp = temp.link
            temp.link = new
    def del_begin(self):
        temp = self.head
        self.head =  self.head.link
        temp = None 
    def del_end(self):
        temp = self.head
        while temp.link.link is not None :
            temp = temp.link
        temp.link = None
    def traverse(self):
        print("Display:")
        if self.head is None:
            print("No element in the list")
        else:
            temp = self.head
            while temp is not None:
                print(temp.data)
                temp = temp.link
            
obj = Linkedlist()
obj.insert_begin(10)
obj.insert_begin(20)
obj.insert_begin(30)
obj.insert_begin(40)
obj.insert_end(50)
obj.insert_end(33)
obj.insert_end(44)   
obj.traverse()
obj.del_begin()
obj.traverse()
obj.del_end()
obj.traverse()
# Out:
# Display:
# 40
# 30
# 20
# 10
# 50
# 33
# 44
# Display:
# 30
# 20
# 10
# 50
# 33
# 44
# Display:
# 30
# 20
# 10
# 50
# 33

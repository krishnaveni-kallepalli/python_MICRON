# %%
import matplotlib.pyplot as plt
x =[1, 2, 3, 4, 5]
y =[2, 4, 6, 8, 10]
    
plt.plot(x, y)
plt.axis([0, 10, 1, 15])
plt.show()

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
y=[2,4,6,8,10]
plt.plot(x,y)
plt.axis([1,10,2,20])
plt.show()

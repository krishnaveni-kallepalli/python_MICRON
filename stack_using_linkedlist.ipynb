# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.link = None
class Stack:
    def __init__(self):
        self.head = None 
    def push(self,data):
        new = Node(data)
        if self.head is None:
            self.head = new
        else:
            temp = self.head
            while temp.link is not None:
                temp = temp.link 
            temp.link = new 
    def pop(self):
        temp = self.head 
        while temp.link.link is not None:
            temp = temp.link 
        temp.link = None
    def display(self):
        print("Display:")
        temp = self.head
        while temp is not None:
            print(temp.data)
            temp = temp.link
            
obj = Stack()
obj.push(1)
obj.push(2)
obj.push(3)
obj.push(4)
obj.push(5)
obj.display()
obj.pop()
obj.display()
# Out:
# Display:
# 1
# 2
# 3
# 4
# 5
# Display:
# 1
# 2
# 3
# 4

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.link = None
        
class Stack:
    def __init__(self):
        self.head = None 
        self.top  = 0
        self.maxsize = int(input("Stack size:"))
    def push(self,data):
        new = Node(data)
        if(self.top<self.maxsize):
            if self.head is None:
                self.head = new
                self.top = self.top + 1
                print(self.top)
            else:
                temp = self.head
                while temp.link is not None:
                    temp = temp.link 
                temp.link = new 
                self.top = self.top + 1
        else:
            print("Stack over flow")
    def pop(self):
        temp = self.head 
        while temp.link.link is not None:
            temp = temp.link 
        temp.link = None
    def display(self):
        print("Display:")
        temp = self.head
        while temp is not None:
            print(temp.data)
            temp = temp.link
            
obj = Stack()
for self.top in range(0,self.maxsize):
    if self.top<self.max size:
        x=int(input("Enter data"))
        obj.push(x)

obj.display()
obj.pop()
obj.display()
'''
class Node:
    def __init__(self, data, next=None):
        self.data = data
        self.next = next

class Stack:
    def __init__(self):
        self.bottom = None
        self.top = None
        self.length = 0

    def peek(self):
        return self.top.data if self.top != None else None

    def push(self, data):
        NewNode = Node(data)
        if self.length == 0:
            self.bottom = self.top = NewNode
        else:
            top = self.top
            self.top = NewNode
            self.top.next = top
        self.length += 1
        return self

    def pop(self):
        length = self.length
        top = self.top
        if length == 0:
            raise IndexError('No items in stack')
        elif self.bottom == top:
            self.bottom = None
        else:
            NextTop = self.top.next
            self.top = NextTop
        self.length -= 1
        return top.data
'''

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.link = None
        
class Stack:
    def __init__(self):
        self.head = None 
        self.top  = 0
        self.maxsize = int(input("Stack size:"))
        for self.top in range(0,self.maxsize):
            if self.top<self.maxsize:
                x=int(input("Enter data"))
                push(x)
    def push(self,data):
        new = Node(data)
        if self.head is None:
            self.head = new
            self.top = self.top + 1
            print(self.top)
        else:
            temp = self.head
            while temp.link is not None:
                temp = temp.link 
            temp.link = new 
            self.top = self.top + 1
    
    def pop(self):
        temp = self.head 
        while temp.link.link is not None:
            temp = temp.link 
        temp.link = None
    def display(self):
        print("Display:")
        temp = self.head
        while temp is not None:
            print(temp.data)
            temp = temp.link
            
obj = Stack()
obj.display()
obj.pop()
obj.display()

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.link = None
        
class Stack:
    def __init__(self):
        self.head = None 
    def push(self,data):
        new = Node(data)
        if self.head is None:
            self.head = new
        else:
            temp = self.head
            while temp.link is not None:
                temp = temp.link 
            temp.link = new 
        
    def pop(self):
        temp = self.head 
        while temp.link.link is not None:
            temp = temp.link 
        temp.link = None
    def display(self):
        print("Display:")
        temp = self.head
        while temp is not None:
            print(temp.data)
            temp = temp.link
            
obj = Stack()
maxsize = int(input("Enter size:"))
top = 0
for top in range(0,maxsize):
    if top<maxsize:
        x=int(input("Enter data"))
        obj.push(x)
        top = top + 1
obj.display()
obj.pop()
obj.display()
# Out:
# Enter size:3
# Enter data1
# Enter data2
# Enter data3
# Display:
# 1
# 2
# 3
# Display:
# 1
# 2

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.link = None
        
class Stack:
    def __init__(self,top,maxsize):
        self.head = None 
        self.top = top
        self.maxsize = maxsize
    def push(self,data):
        new = Node(data)
        if self.head is None:
            self.head = new
            self.top = self.top +1
        else:
            temp = self.head
            while temp.link is not None:
                temp = temp.link 
            temp.link = new 
            self.top = self.top+1
    def pop(self):
        temp = self.head 
        while temp.link.link is not None:
            temp = temp.link 
        temp.link = None
        self.top = self.top - 1
    def checksize(self):
        if self.top == 0:
            print("Stack is Empty")
            print(self.top)
        elif self.top >= self.maxsize:
            print("Stack is full ")
            print(self.top)
        elif self.top > 0 and self.top < self.maxsize:
            print("Stack size:",self.top)
    def display(self):
        print("Display:")
        temp = self.head
        while temp is not None:
            print(temp.data)
            temp = temp.link
maxsize = int(input("Enter size:"))
top = 0       
obj = Stack(top,maxsize)
obj.checksize()
for top in range(0,maxsize):
    if top<maxsize:
        x=int(input("Enter data : "))
        obj.push(x)
        top = top + 1
obj.display()
obj.checksize()
obj.pop()
obj.display()
obj.checksize()
# Out:
# Enter size:3
# Stack is Empty
# 0
# Enter data : 1
# Enter data : 2
# Enter data : 3
# Display:
# 1
# 2
# 3
# Stack is full
# 3
# Display:
# 1
# 2
# Stack size: 2
# Display:
# 1
# 2
# 2
# Stack is full
# 3
# Display:
# 1
# 2
# 2
# 3
# Stack is full
# 4

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.link = None
        
class Stack:
    def __init__(self,top,maxsize):
        self.head = None 
        self.top = top
        self.maxsize = maxsize
    def push(self,data):
        new = Node(data)
        if self.head is None:
            self.head = new
            self.top = self.top +1
        else:
            temp = self.head
            while temp.link is not None:
                temp = temp.link 
            temp.link = new 
            self.top = self.top+1
    def pop(self):
        temp = self.head 
        while temp.link.link is not None:
            temp = temp.link 
        print("popped element:",temp.link.data)
        temp.link = None
        self.top = self.top - 1
    def checksize(self):
        if self.top == 0:
            print("Stack is Empty")
            print(self.top)
        elif self.top >= self.maxsize:
            print("Stack is full ")
            print(self.top)
        elif self.top > 0 and self.top < self.maxsize:
            print("Stack size:",self.top)
    def peek(self):
        temp = self.head 
        while temp.link.link is not None:
            temp = temp.link 
        print("Last element:",temp.link.data)
    def display(self):
        print("Display:")
        temp = self.head
        while temp is not None:
            print(temp.data)
            temp = temp.link
maxsize = int(input("Enter size:"))
top = 0       
obj = Stack(top,maxsize)
obj.checksize()
for top in range(0,maxsize):
    if top<maxsize:
        x=int(input("Enter data : "))
        obj.push(x)
        top = top + 1
    
obj.display()
obj.pop()
obj.display()
obj.checksize()
obj.peek()
# Out:
# Enter size:4
# Stack is Empty
# 0
# Enter data : 1
# Enter data : 2
# Enter data : 3
# Enter data : 4
# Display:
# 1
# 2
# 3
# 4
# popped element: 4
# Display:
# 1
# 2
# 3
# Stack size: 3
# Last element: 3

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.link = None
        
class Stack:
    def __init__(self,top,maxsize):
        self.head = None 
        self.top = top
        self.maxsize = maxsize
    def push(self,data):
        new = Node(data)
        if self.head is None:
            self.head = new
            self.top = self.top +1
        else:
            temp = self.head
            while temp.link is not None:
                temp = temp.link 
            temp.link = new 
            self.top = self.top+1
    def pop(self):
        temp = self.head 
        while temp.link.link is not None:
            temp = temp.link 
        print("popped element:",temp.link.data)
        temp.link = None
        self.top = self.top - 1
    def checksize(self):
        if self.top == 0:
            print("Stack is Empty")
            print(self.top)
        elif self.top >= self.maxsize:
            print("Stack is full ")
            print(self.top)
        elif self.top > 0 and self.top < self.maxsize:
            print("Stack size:",self.top)
    def peek(self):
        temp = self.head 
        while temp.link is not None:
            temp = temp.link 
        print("Last element:",temp.data)
    def display(self):
        print("Display:")
        temp = self.head
        while temp is not None:
            print(temp.data)
            temp = temp.link
maxsize = int(input("Enter size:"))
top = 0       
obj = Stack(top,maxsize)
obj.checksize()
for top in range(0,maxsize):
    if top<maxsize:
        x=int(input("Enter data : "))
        obj.push(x)
        top = top + 1
    
obj.display()
obj.pop()
obj.display()
obj.checksize()
obj.peek()
